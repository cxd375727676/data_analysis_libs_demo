# %%
import pyecharts
import pandas as pd
import numpy as np
from pyecharts import options as opts
from snapshot_phantomjs import snapshot
from pyecharts.render import make_snapshot

# %%
index = ['指标' + str(i) for i in range(1,7)]
data_1 = [5, 20, 36, 10, 75, 90]
data_2 = [15, 6, 45, 20, 35, 66]

# %% [markdown]
# ##  1. <font color=red>柱状图</font>

# %%
bar = pyecharts.charts.Bar()
bar.set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
bar.add_xaxis(index)
bar.add_yaxis("系列1", [5, 20, 36, 10, 75, 90])
bar.add_yaxis("系列2", [15, 6, 45, 20, 35, 66])

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="e82c509cf30049aab543d9e9dd7347c8" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_e82c509cf30049aab543d9e9dd7347c8 = echarts.init(
#             document.getElementById('e82c509cf30049aab543d9e9dd7347c8'), 'white', {renderer: 'canvas'});
#         var option_e82c509cf30049aab543d9e9dd7347c8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7cfb\u52171",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7cfb\u52172",
#             "data": [
#                 15,
#                 6,
#                 45,
#                 20,
#                 35,
#                 66
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7cfb\u52171",
#                 "\u7cfb\u52172"
#             ],
#             "selected": {
#                 "\u7cfb\u52171": true,
#                 "\u7cfb\u52172": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6307\u68071",
#                 "\u6307\u68072",
#                 "\u6307\u68073",
#                 "\u6307\u68074",
#                 "\u6307\u68075",
#                 "\u6307\u68076"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_e82c509cf30049aab543d9e9dd7347c8.setOption(option_e82c509cf30049aab543d9e9dd7347c8);
#     });
# </script>

# %%
bar.render(r'.\output\bar.html')   # 保存为html文件(返回html文件的绝对路径)
# Out:
# 'C:\\Users\\Administrator\\Desktop\\data_analysis_libs_demo\\pyecharts_demo\\output\\bar.html'

# %%
make_snapshot(snapshot, r'.\output\bar.html', r'.\output\bar.png')   # 将保存的html文件渲染为图片
make_snapshot(snapshot, r'.\output\bar.html', r'.\output\bar.pdf')   # 渲染为pdf文件

# %% [markdown]
# ## 2. <font color=red>折线图</font>

# %%
line = pyecharts.charts.Line()
line.set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
line.add_xaxis(index)
line.add_yaxis("系列1", [5, 20, 36, 10, 75, 90])
line.add_yaxis("系列2", [15, 6, 45, 20, 35, 66])

line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="ed939ac91b254dcbaf03b0ee4a2415c5" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_ed939ac91b254dcbaf03b0ee4a2415c5 = echarts.init(
#             document.getElementById('ed939ac91b254dcbaf03b0ee4a2415c5'), 'white', {renderer: 'canvas'});
#         var option_ed939ac91b254dcbaf03b0ee4a2415c5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u7cfb\u52171",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u6307\u68071",
#                     5
#                 ],
#                 [
#                     "\u6307\u68072",
#                     20
#                 ],
#                 [
#                     "\u6307\u68073",
#                     36
#                 ],
#                 [
#                     "\u6307\u68074",
#                     10
#                 ],
#                 [
#                     "\u6307\u68075",
#                     75
#                 ],
#                 [
#                     "\u6307\u68076",
#                     90
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u7cfb\u52172",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u6307\u68071",
#                     15
#                 ],
#                 [
#                     "\u6307\u68072",
#                     6
#                 ],
#                 [
#                     "\u6307\u68073",
#                     45
#                 ],
#                 [
#                     "\u6307\u68074",
#                     20
#                 ],
#                 [
#                     "\u6307\u68075",
#                     35
#                 ],
#                 [
#                     "\u6307\u68076",
#                     66
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7cfb\u52171",
#                 "\u7cfb\u52172"
#             ],
#             "selected": {
#                 "\u7cfb\u52171": true,
#                 "\u7cfb\u52172": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6307\u68071",
#                 "\u6307\u68072",
#                 "\u6307\u68073",
#                 "\u6307\u68074",
#                 "\u6307\u68075",
#                 "\u6307\u68076"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_ed939ac91b254dcbaf03b0ee4a2415c5.setOption(option_ed939ac91b254dcbaf03b0ee4a2415c5);
#     });
# </script>

# %%
line.render(r'.\output\line.html')
make_snapshot(snapshot, r'.\output\line.html', r'.\output\line.png')
make_snapshot(snapshot, r'.\output\line.html', r'.\output\line.pdf')

# %% [markdown]
# ## 3. <font color=red>散点图</font>

# %%
scatter = pyecharts.charts.Scatter()
scatter.set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
scatter.add_xaxis(index)
scatter.add_yaxis("系列1", [5, 20, 36, 10, 75, 90])
scatter.add_yaxis("系列2", [15, 6, 45, 20, 35, 66])

scatter.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="296330f47e0b4d3983aa37ee7b0b3d72" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_296330f47e0b4d3983aa37ee7b0b3d72 = echarts.init(
#             document.getElementById('296330f47e0b4d3983aa37ee7b0b3d72'), 'white', {renderer: 'canvas'});
#         var option_296330f47e0b4d3983aa37ee7b0b3d72 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u7cfb\u52171",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u6307\u68071",
#                     5
#                 ],
#                 [
#                     "\u6307\u68072",
#                     20
#                 ],
#                 [
#                     "\u6307\u68073",
#                     36
#                 ],
#                 [
#                     "\u6307\u68074",
#                     10
#                 ],
#                 [
#                     "\u6307\u68075",
#                     75
#                 ],
#                 [
#                     "\u6307\u68076",
#                     90
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u7cfb\u52172",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u6307\u68071",
#                     15
#                 ],
#                 [
#                     "\u6307\u68072",
#                     6
#                 ],
#                 [
#                     "\u6307\u68073",
#                     45
#                 ],
#                 [
#                     "\u6307\u68074",
#                     20
#                 ],
#                 [
#                     "\u6307\u68075",
#                     35
#                 ],
#                 [
#                     "\u6307\u68076",
#                     66
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7cfb\u52171",
#                 "\u7cfb\u52172"
#             ],
#             "selected": {
#                 "\u7cfb\u52171": true,
#                 "\u7cfb\u52172": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6307\u68071",
#                 "\u6307\u68072",
#                 "\u6307\u68073",
#                 "\u6307\u68074",
#                 "\u6307\u68075",
#                 "\u6307\u68076"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_296330f47e0b4d3983aa37ee7b0b3d72.setOption(option_296330f47e0b4d3983aa37ee7b0b3d72);
#     });
# </script>

# %%
scatter.render(r'.\output\scatter.html')
make_snapshot(snapshot, r'.\output\scatter.html', r'.\output\scatter.png')
make_snapshot(snapshot, r'.\output\scatter.html', r'.\output\scatter.pdf')

# %% [markdown]
# ## 4. <font color=red>雷达图</font>

# %%
maxes = [20, 30, 50, 30, 80, 100]    # 为每个指标设置一个最大值（即每个“维度”半径代表的数值）
schema = [{'name': name, 'max': max_} for name, max_ in zip(index, maxes)]
schema
# Out:
# [{'name': '指标1', 'max': 20},
#  {'name': '指标2', 'max': 30},
#  {'name': '指标3', 'max': 50},
#  {'name': '指标4', 'max': 30},
#  {'name': '指标5', 'max': 80},
#  {'name': '指标6', 'max': 100}]

# %%
radar = pyecharts.charts.Radar()
radar.add_schema(schema=schema, shape="circle")
radar.set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
radar.add("系列1", [data_1], color="red")
radar.add("系列2", [data_2], color="blue")
radar.set_series_opts(label_opts=opts.LabelOpts(is_show=False))   # 不显示具体数字

radar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="491bb53fde6645d5bdbbd1e50643474a" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_491bb53fde6645d5bdbbd1e50643474a = echarts.init(
#             document.getElementById('491bb53fde6645d5bdbbd1e50643474a'), 'white', {renderer: 'canvas'});
#         var option_491bb53fde6645d5bdbbd1e50643474a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u7cfb\u52171",
#             "data": [
#                 [
#                     5,
#                     20,
#                     36,
#                     10,
#                     75,
#                     90
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": "red"
#                 }
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u7cfb\u52172",
#             "data": [
#                 [
#                     15,
#                     6,
#                     45,
#                     20,
#                     35,
#                     66
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": "blue"
#                 }
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7cfb\u52171",
#                 "\u7cfb\u52172"
#             ],
#             "selected": {
#                 "\u7cfb\u52171": true,
#                 "\u7cfb\u52172": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radar": {
#         "indicator": [
#             {
#                 "name": "\u6307\u68071",
#                 "max": 20
#             },
#             {
#                 "name": "\u6307\u68072",
#                 "max": 30
#             },
#             {
#                 "name": "\u6307\u68073",
#                 "max": 50
#             },
#             {
#                 "name": "\u6307\u68074",
#                 "max": 30
#             },
#             {
#                 "name": "\u6307\u68075",
#                 "max": 80
#             },
#             {
#                 "name": "\u6307\u68076",
#                 "max": 100
#             }
#         ],
#         "shape": "circle",
#         "name": {
#             "textStyle": {}
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         }
#     },
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_491bb53fde6645d5bdbbd1e50643474a.setOption(option_491bb53fde6645d5bdbbd1e50643474a);
#     });
# </script>

# %%
radar.render(r'.\output\radar.html')
make_snapshot(snapshot, r'.\output\radar.html', r'.\output\radar.png')
make_snapshot(snapshot, r'.\output\radar.html', r'.\output\radar.pdf')

# %% [markdown]
# ## 5. <font color=red>箱线图</font>

# %%
# 每个系列每个指标生成一个序列数据
data_1_expand = (data_1 + np.random.randn(50, 6)).transpose()
data_2_expand = (data_2 + np.random.randn(50, 6)).transpose()

box = pyecharts.charts.Boxplot()
box.set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
box.add_xaxis(index)
box.add_yaxis("系列1", box.prepare_data(data_1_expand))
box.add_yaxis("系列2", box.prepare_data(data_2_expand))

box.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="1772588b6bdb4c2695feede126ca8b1f" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_1772588b6bdb4c2695feede126ca8b1f = echarts.init(
#             document.getElementById('1772588b6bdb4c2695feede126ca8b1f'), 'white', {renderer: 'canvas'});
#         var option_1772588b6bdb4c2695feede126ca8b1f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "\u7cfb\u52171",
#             "data": [
#                 [
#                     2.859689155946759,
#                     4.157479312088981,
#                     4.8585512456284805,
#                     5.924805506718901,
#                     7.727111241877033
#                 ],
#                 [
#                     17.83257952680493,
#                     19.198721080974913,
#                     20.10971341972963,
#                     20.918682369824424,
#                     22.517868173462492
#                 ],
#                 [
#                     34.026581224087494,
#                     35.11368273352613,
#                     35.82263865894657,
#                     36.45622312042897,
#                     38.548293641687366
#                 ],
#                 [
#                     7.125612251837715,
#                     9.400677086565086,
#                     9.96032675552678,
#                     10.528476596330632,
#                     12.220818166409176
#                 ],
#                 [
#                     72.79975112048623,
#                     74.21226721248436,
#                     74.89881213924727,
#                     75.86602266807667,
#                     77.64128530635038
#                 ],
#                 [
#                     87.4617804433982,
#                     89.05675338321953,
#                     89.69220056875884,
#                     90.68454003654325,
#                     91.86207518949998
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "\u7cfb\u52172",
#             "data": [
#                 [
#                     12.958884899623264,
#                     14.191662811804116,
#                     14.688356959361514,
#                     15.719875378026277,
#                     16.88459589635155
#                 ],
#                 [
#                     4.377956139082059,
#                     5.398078908201807,
#                     6.0796167239077175,
#                     6.832719730673025,
#                     8.147388032812788
#                 ],
#                 [
#                     43.14797857722956,
#                     44.416515886524316,
#                     45.004217556804,
#                     46.06459067871163,
#                     47.83009292963926
#                 ],
#                 [
#                     17.68408308362119,
#                     19.21654272323986,
#                     19.85970759334222,
#                     20.504162260637674,
#                     21.53013225664435
#                 ],
#                 [
#                     32.79027939027461,
#                     34.116660447470544,
#                     34.629491807294144,
#                     35.416898267925475,
#                     37.120091882110074
#                 ],
#                 [
#                     63.7854915788741,
#                     65.1646443777121,
#                     65.93670747778367,
#                     66.44990165151188,
#                     68.46889797358223
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7cfb\u52171",
#                 "\u7cfb\u52172"
#             ],
#             "selected": {
#                 "\u7cfb\u52171": true,
#                 "\u7cfb\u52172": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6307\u68071",
#                 "\u6307\u68072",
#                 "\u6307\u68073",
#                 "\u6307\u68074",
#                 "\u6307\u68075",
#                 "\u6307\u68076"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_1772588b6bdb4c2695feede126ca8b1f.setOption(option_1772588b6bdb4c2695feede126ca8b1f);
#     });
# </script>

# %%
box.render(r'.\output\box.html')
make_snapshot(snapshot, r'.\output\box.html', r'.\output\box.png')
make_snapshot(snapshot, r'.\output\box.html', r'.\output\box.pdf')

# %% [markdown]
# ## 6. <font color=red>漏斗图</font>

# %%
#  单系列数据
funnel = pyecharts.charts.Funnel()
funnel.set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"),
                      legend_opts=opts.LegendOpts(is_show=False)                     # 不显示图例
                      )
funnel.add(series_name="系列1", data_pair=list(zip(index, data_1)), label_opts=opts.LabelOpts(position="inside"))  # label位于图中

funnel.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="dab0faffeba040dcba203e1d492d2439" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_dab0faffeba040dcba203e1d492d2439 = echarts.init(
#             document.getElementById('dab0faffeba040dcba203e1d492d2439'), 'white', {renderer: 'canvas'});
#         var option_dab0faffeba040dcba203e1d492d2439 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u7cfb\u52171",
#             "data": [
#                 {
#                     "name": "\u6307\u68071",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u6307\u68072",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u6307\u68073",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u6307\u68074",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u6307\u68075",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u6307\u68076",
#                     "value": 90
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6307\u68071",
#                 "\u6307\u68076",
#                 "\u6307\u68074",
#                 "\u6307\u68075",
#                 "\u6307\u68073",
#                 "\u6307\u68072"
#             ],
#             "selected": {
#                 "\u6307\u68071": true,
#                 "\u6307\u68072": true,
#                 "\u6307\u68073": true,
#                 "\u6307\u68074": true,
#                 "\u6307\u68075": true,
#                 "\u6307\u68076": true
#             },
#             "show": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_dab0faffeba040dcba203e1d492d2439.setOption(option_dab0faffeba040dcba203e1d492d2439);
#     });
# </script>

# %%
funnel.render(r'.\output\funnel.html')
make_snapshot(snapshot, r'.\output\funnel.html', r'.\output\funnel.png')
make_snapshot(snapshot, r'.\output\funnel.html', r'.\output\funnel.pdf')

# %% [markdown]
# ## 7. <font color=red>饼图</font>

# %%
#  单系列数据
pie = pyecharts.charts.Pie()
pie.set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"),
                    legend_opts=opts.LegendOpts(orient="vertical", pos_top="15%", pos_left="2%")
                   )
pie.add(series_name="系列1", 
        data_pair=list(zip(index, data_1)),
        radius=["40%", "75%"]     # [内径:str，外径:str]
        )

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="25b75b04dacc40b7bf75751355033328" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_25b75b04dacc40b7bf75751355033328 = echarts.init(
#             document.getElementById('25b75b04dacc40b7bf75751355033328'), 'white', {renderer: 'canvas'});
#         var option_25b75b04dacc40b7bf75751355033328 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u7cfb\u52171",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u6307\u68071",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u6307\u68072",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u6307\u68073",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u6307\u68074",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u6307\u68075",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u6307\u68076",
#                     "value": 90
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6307\u68071",
#                 "\u6307\u68072",
#                 "\u6307\u68073",
#                 "\u6307\u68074",
#                 "\u6307\u68075",
#                 "\u6307\u68076"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_25b75b04dacc40b7bf75751355033328.setOption(option_25b75b04dacc40b7bf75751355033328);
#     });
# </script>

# %%
pie.render(r'.\output\pie.html')
make_snapshot(snapshot, r'.\output\pie.html', r'.\output\pie.png')
make_snapshot(snapshot, r'.\output\pie.html', r'.\output\pie.pdf')

# %% [markdown]
# ## 8. <font color=red>旭日图</font>——旭日图用来展现多层次饼图

# %%
sale_data_df = pd.DataFrame({'销量（万件）': [22,12,18,87,88,25,16,24,89,16,19,86,23,21]},
                        index=[['A公司']*5 + ['B公司']*4 + ['C公司']*5,
                               ['女装']*3 + ['男装']*3 + ['童装'] + ['女装']*2 + ['男装']*4 +['童装'],
                               ['上衣','裙子','裤子','上衣','裤子','裤子',None,'上衣','裙子','上衣','裤子','内衣','运动衫',None]])                              
sale_data_df  # 数据的DataFrame展示
# Out:
#             销量（万件）
# A公司 女装 上衣       22
#        裙子       12
#        裤子       18
#     男装 上衣       87
#        裤子       88
# B公司 男装 裤子       25
#     童装 NaN      16
#     女装 上衣       24
#        裙子       89
# C公司 男装 上衣       16
#        裤子       19
#        内衣       86
#        运动衫      23
#     童装 NaN      21

# %%
# 旭日图要求的树状层次数据格式
sale_data_1 = [
    opts.SunburstItem(name="A公司", 
                      children=[opts.SunburstItem(name="女装", 
                                                  children=[opts.SunburstItem(name="上衣", value=22),
                                                            opts.SunburstItem(name="裙子", value=12),
                                                            opts.SunburstItem(name="裤子", value=18)
                                                           ]
                                                 ),
                               opts.SunburstItem(name="男装",
                                                children=[opts.SunburstItem(name="上衣", value=87),
                                                          opts.SunburstItem(name="裤子", value=88)
                                                         ]
                                                )
                               ]
                     ),
    opts.SunburstItem(name="B公司",
                     children=[opts.SunburstItem(name="男装", children=[opts.SunburstItem(name="裤子", value=25)]),
                               opts.SunburstItem(name="童装", value=16),
                               opts.SunburstItem(name="女装", children=[opts.SunburstItem(name="上衣", value=24),
                                                                        opts.SunburstItem(name="裙子", value=89)
                                                                       ]
                                                )
                              ]
                     ),
     opts.SunburstItem(name="C公司",
                     children=[opts.SunburstItem(name="男装", children=[opts.SunburstItem(name="上衣", value=16),
                                                                        opts.SunburstItem(name="裤子", value=19),
                                                                        opts.SunburstItem(name="内衣", value=86),
                                                                        opts.SunburstItem(name="运动衫", value=23)
                                                                       ]
                                                ),
                               opts.SunburstItem(name="童装", value=21)
                              ]
                      )
]

sunburst = pyecharts.charts.Sunburst()
sunburst.set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
sunburst.add(series_name="", data_pair=sale_data_1)

sunburst.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="801b72b1699e49558452906708d1c05e" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_801b72b1699e49558452906708d1c05e = echarts.init(
#             document.getElementById('801b72b1699e49558452906708d1c05e'), 'white', {renderer: 'canvas'});
#         var option_801b72b1699e49558452906708d1c05e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sunburst",
#             "data": [
#                 {
#                     "name": "A\u516c\u53f8",
#                     "target": "blank",
#                     "children": [
#                         {
#                             "name": "\u5973\u88c5",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 22,
#                                     "name": "\u4e0a\u8863",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 12,
#                                     "name": "\u88d9\u5b50",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 18,
#                                     "name": "\u88e4\u5b50",
#                                     "target": "blank"
#                                 }
#                             ]
#                         },
#                         {
#                             "name": "\u7537\u88c5",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 87,
#                                     "name": "\u4e0a\u8863",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 88,
#                                     "name": "\u88e4\u5b50",
#                                     "target": "blank"
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "name": "B\u516c\u53f8",
#                     "target": "blank",
#                     "children": [
#                         {
#                             "name": "\u7537\u88c5",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 25,
#                                     "name": "\u88e4\u5b50",
#                                     "target": "blank"
#                                 }
#                             ]
#                         },
#                         {
#                             "value": 16,
#                             "name": "\u7ae5\u88c5",
#                             "target": "blank"
#                         },
#                         {
#                             "name": "\u5973\u88c5",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 24,
#                                     "name": "\u4e0a\u8863",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 89,
#                                     "name": "\u88d9\u5b50",
#                                     "target": "blank"
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "name": "C\u516c\u53f8",
#                     "target": "blank",
#                     "children": [
#                         {
#                             "name": "\u7537\u88c5",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 16,
#                                     "name": "\u4e0a\u8863",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 19,
#                                     "name": "\u88e4\u5b50",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 86,
#                                     "name": "\u5185\u8863",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 23,
#                                     "name": "\u8fd0\u52a8\u886b",
#                                     "target": "blank"
#                                 }
#                             ]
#                         },
#                         {
#                             "value": 21,
#                             "name": "\u7ae5\u88c5",
#                             "target": "blank"
#                         }
#                     ]
#                 }
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "highlightPolicy": "descendant",
#             "nodeClick": "rootToNode",
#             "sort": "desc",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_801b72b1699e49558452906708d1c05e.setOption(option_801b72b1699e49558452906708d1c05e);
#     });
# </script>

# %%
sunburst.render(r'.\output\sunburst.html')
make_snapshot(snapshot, r'.\output\sunburst.html', r'.\output\sunburst.png')
make_snapshot(snapshot, r'.\output\sunburst.html', r'.\output\sunburst.pdf')

# %%
# 字典\列表嵌套格式
sale_data_2 = [
    {
        "name": "A公司", 
        "children": [
            {
                "name": "女装", 
                "children": [
                    {"name": "上衣", "value": 22},
                    {"name": "裙子", "value": 12},
                    {"name": "裤子", "value": 18}
                 ]
            },
            {
                "name": "男装",
                "children": [
                    {"name": "上衣", "value": 87},
                    {"name": "裤子", "value" :88},
                ]
            }
        ]
    },
    {
        "name": "B公司",
        "children": [
            {
                "name": "男装", 
                "children": [{"name": "裤子", "value": 25}]
            },
            {"name": "童装", "value": 16},
            {
                "name": "女装", 
                "children": [
                            {"name": "上衣", "value": 24},
                            {"name": "裙子", "value": 89}
                ]
            }
        ]
    },
    {
         "name": "C公司",
         "children": [
             {
                 "name": "男装", 
                 "children": [
                     {"name": "上衣", "value": 16},
                     {"name": "裤子", "value": 19},
                     {"name": "内衣", "value": 86},
                     {"name": "运动衫", "value": 23}
                 ]
             },
             {"name": "童装", "value": 21}
        ]
    }
]

sunburst = pyecharts.charts.Sunburst()
sunburst.set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
sunburst.add(series_name="", data_pair=sale_data_2)

sunburst.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="18d78c58672e47649ba19819c42935d1" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_18d78c58672e47649ba19819c42935d1 = echarts.init(
#             document.getElementById('18d78c58672e47649ba19819c42935d1'), 'white', {renderer: 'canvas'});
#         var option_18d78c58672e47649ba19819c42935d1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sunburst",
#             "data": [
#                 {
#                     "name": "A\u516c\u53f8",
#                     "children": [
#                         {
#                             "name": "\u5973\u88c5",
#                             "children": [
#                                 {
#                                     "name": "\u4e0a\u8863",
#                                     "value": 22
#                                 },
#                                 {
#                                     "name": "\u88d9\u5b50",
#                                     "value": 12
#                                 },
#                                 {
#                                     "name": "\u88e4\u5b50",
#                                     "value": 18
#                                 }
#                             ]
#                         },
#                         {
#                             "name": "\u7537\u88c5",
#                             "children": [
#                                 {
#                                     "name": "\u4e0a\u8863",
#                                     "value": 87
#                                 },
#                                 {
#                                     "name": "\u88e4\u5b50",
#                                     "value": 88
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "name": "B\u516c\u53f8",
#                     "children": [
#                         {
#                             "name": "\u7537\u88c5",
#                             "children": [
#                                 {
#                                     "name": "\u88e4\u5b50",
#                                     "value": 25
#                                 }
#                             ]
#                         },
#                         {
#                             "name": "\u7ae5\u88c5",
#                             "value": 16
#                         },
#                         {
#                             "name": "\u5973\u88c5",
#                             "children": [
#                                 {
#                                     "name": "\u4e0a\u8863",
#                                     "value": 24
#                                 },
#                                 {
#                                     "name": "\u88d9\u5b50",
#                                     "value": 89
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "name": "C\u516c\u53f8",
#                     "children": [
#                         {
#                             "name": "\u7537\u88c5",
#                             "children": [
#                                 {
#                                     "name": "\u4e0a\u8863",
#                                     "value": 16
#                                 },
#                                 {
#                                     "name": "\u88e4\u5b50",
#                                     "value": 19
#                                 },
#                                 {
#                                     "name": "\u5185\u8863",
#                                     "value": 86
#                                 },
#                                 {
#                                     "name": "\u8fd0\u52a8\u886b",
#                                     "value": 23
#                                 }
#                             ]
#                         },
#                         {
#                             "name": "\u7ae5\u88c5",
#                             "value": 21
#                         }
#                     ]
#                 }
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "highlightPolicy": "descendant",
#             "nodeClick": "rootToNode",
#             "sort": "desc",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_18d78c58672e47649ba19819c42935d1.setOption(option_18d78c58672e47649ba19819c42935d1);
#     });
# </script>

# %% [markdown]
# ## 9. <font color=red>词云图</font>

# %%
words = [
    ("Sam S Club", 10000),
    ("Macys", 6181),
    ("Amy Schumer", 4386),
    ("Jurassic World", 4055),
    ("Charter Communications", 2467),
    ("Chick Fil A", 2244),
    ("Planet Fitness", 1868),
    ("Pitch Perfect", 1484),
    ("Express", 1112),
    ("Home", 865),
    ("Johnny Depp", 847),
    ("Lena Dunham", 582),
    ("Lewis Hamilton", 555),
    ("KXAN", 550),
    ("Mary Ellen Mark", 462),
    ("Farrah Abraham", 366),
    ("Rita Ora", 360),
    ("Serena Williams", 282),
    ("NCAA baseball tournament", 273),
    ("Point Break", 265),
]

wordcloud = pyecharts.charts.WordCloud()
wordcloud.set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
wordcloud.add(series_name="", data_pair=words, word_size_range=[20, 100])

wordcloud.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#     <div id="15f77a355a03430c8b5e62ba27592a1b" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-wordcloud'], function(echarts) {
#         var chart_15f77a355a03430c8b5e62ba27592a1b = echarts.init(
#             document.getElementById('15f77a355a03430c8b5e62ba27592a1b'), 'white', {renderer: 'canvas'});
#         var option_15f77a355a03430c8b5e62ba27592a1b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "Sam S Club",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,128,64)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Macys",
#                     "value": 6181,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(70,82,116)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Amy Schumer",
#                     "value": 4386,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(157,73,58)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Jurassic World",
#                     "value": 4055,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,40,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Charter Communications",
#                     "value": 2467,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(79,52,30)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Chick Fil A",
#                     "value": 2244,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,78,25)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Planet Fitness",
#                     "value": 1868,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(2,113,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Pitch Perfect",
#                     "value": 1484,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(133,48,100)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Express",
#                     "value": 1112,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(39,105,44)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Home",
#                     "value": 865,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(27,75,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Johnny Depp",
#                     "value": 847,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(81,159,105)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Lena Dunham",
#                     "value": 582,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,10,14)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Lewis Hamilton",
#                     "value": 555,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,106,16)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "KXAN",
#                     "value": 550,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,1,80)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Mary Ellen Mark",
#                     "value": 462,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,38,158)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Farrah Abraham",
#                     "value": 366,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(19,123,48)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Rita Ora",
#                     "value": 360,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,102,151)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Serena Williams",
#                     "value": 282,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(90,81,33)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "NCAA baseball tournament",
#                     "value": 273,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,128,37)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Point Break",
#                     "value": 265,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(45,51,41)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# }

# %%
wordcloud.render(r'.\output\wordcloud.html')
make_snapshot(snapshot, r'.\output\wordcloud.html', r'.\output\wordcloud.png')
make_snapshot(snapshot, r'.\output\wordcloud.html', r'.\output\wordcloud.pdf')

# %% [markdown]
# ## 10. <font color=red>仪表盘</font>

# %%
gauge = pyecharts.charts.Gauge()
gauge.set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"),
                      legend_opts=opts.LegendOpts(is_show=False))
gauge.add(series_name="业务指标", 
          data_pair=[("完成率", 55.5)],
          split_number=5       # 默认刻度10段
         )

gauge.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="cd253f6eb3184a239652406170d6baf4" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_cd253f6eb3184a239652406170d6baf4 = echarts.init(
#             document.getElementById('cd253f6eb3184a239652406170d6baf4'), 'white', {renderer: 'canvas'});
#         var option_cd253f6eb3184a239652406170d6baf4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "name": "\u4e1a\u52a1\u6307\u6807",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 5,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 55.5
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e1a\u52a1\u6307\u6807"
#             ],
#             "selected": {
#                 "\u4e1a\u52a1\u6307\u6807": true
#             },
#             "show": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ]
# };
#         chart_cd253f6eb3184a239652406170d6baf4.setOption(option_cd253f6eb3184a239652406170d6baf4);
#     });
# </script>

# %%
gauge.render(r'.\output\gauge.html')
make_snapshot(snapshot, r'.\output\gauge.html', r'.\output\gauge.png')
make_snapshot(snapshot, r'.\output\gauge.html', r'.\output\gauge.pdf')

# %% [markdown]
# ## 11. <font color=red>Geo-Lines</font>

# %%
from pyecharts.globals import ChartType, SymbolType


geo = pyecharts.charts.Geo()
geo.set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"),
                      legend_opts=opts.LegendOpts(is_show=False)
                      )
geo.add_schema(maptype="china")

geo.add("", 
        [("广州", 55), ("北京", 66), ("杭州", 77), ("重庆", 88)], 
        type_=ChartType.EFFECT_SCATTER, 
        color="#00FFFF")  # 省份

geo.add("", 
        [("广州", "上海"), ("广州", "北京"), ("广州", "杭州"), ("广州", "重庆")],
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(symbol=SymbolType.ARROW, symbol_size=6, color="blue"),
        linestyle_opts=opts.LineStyleOpts(curve=0.2))   # 路径

geo.set_series_opts(label_opts=opts.LabelOpts(is_show=False))


geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="020a49fef4ab468caec08bbb68791a8f" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_020a49fef4ab468caec08bbb68791a8f = echarts.init(
#             document.getElementById('020a49fef4ab468caec08bbb68791a8f'), 'white', {renderer: 'canvas'});
#         var option_020a49fef4ab468caec08bbb68791a8f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#00FFFF",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         55
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         66
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         77
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         88
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "lines",
#             "coordinateSystem": "geo",
#             "zlevel": 3,
#             "effect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4,
#                 "color": "blue",
#                 "symbol": "arrow",
#                 "symbolSize": 6
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "polyline": false,
#             "large": false,
#             "largeThreshold": 2000,
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde->\u4e0a\u6d77",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             121.473701,
#                             31.230416
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.407526,
#                             39.90403
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u676d\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             120.19,
#                             30.26
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u91cd\u5e86",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             106.551556,
#                             29.563009
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0.2,
#                 "type": "solid"
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u526f\u6807\u9898"
#         }
#     ],
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#         chart_020a49fef4ab468caec08bbb68791a8f.setOption(option_020a49fef4ab468caec08bbb68791a8f);
#     });
# </script>

# %%
geo.render(r'.\output\geo.html')
make_snapshot(snapshot, r'.\output\geo.html', r'.\output\geo.png')
make_snapshot(snapshot, r'.\output\geo.html', r'.\output\geo.pdf')
